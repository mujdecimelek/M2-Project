# %%
import time
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# Decorator for measuring execution time
def calculate_execution_time(func):
    def wrapper(*args, **kwargs):
        start_time = time.time()
        result = func(*args, **kwargs)
        end_time = time.time()
        execution_time = end_time - start_time
        print(f"Execution time for {func.__name__}: {execution_time} seconds")
        return result
    return wrapper

# %%
# Load the dataset
@calculate_execution_time
def load_dataset(file_path):
    data = pd.read_csv(file_path)
    return data

# %%
# Define the file path of the dataset
file_path = "C:\\Users\\CaC\\Desktop\\retail_sales_dataset.csv"

# %%
# Load the dataset
data = load_dataset(file_path)
plt.tight_layout()
# Out:
# Execution time for load_dataset: 0.010599374771118164 seconds

# %%
# Display general information about the dataset
print("\nGeneral Information About the Dataset:")
print(data.info())
# Out:
# General Information About the Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB
# None

# %%
#I can use the dataset at my disposal to identify the reasons for the decline in sales data and to increase customer satisfaction in general

# Gender distribution plot
plt.figure(figsize=(8, 6))
sns.countplot(x='Gender', data=data)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Total')
plt.show()

# %%
# Age distribution plot
plt.figure(figsize=(10, 6))
sns.histplot(data['Age'], bins=20, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Total')
plt.show()

# %%
# Product category distribution plot
plt.figure(figsize=(12, 6))
sns.countplot(x='Product Category', data=data)
plt.title('Product Category Distribution')
plt.xlabel('Product Category')
plt.ylabel('Total')
plt.xticks(rotation=45)
plt.show()

# %%
# Define age groups
young_age = range(18, 35)
middle_age = range(35, 55)
old_age = range(55, 100)

# Segment customers by age groups and count product categories
young_customers = data[data['Age'].isin(young_age)]
middle_age_customers = data[data['Age'].isin(middle_age)]
old_customers = data[data['Age'].isin(old_age)]

# Count product categories sold in each age group
young_product_counts = young_customers['Product Category'].value_counts()
middle_age_product_counts = middle_age_customers['Product Category'].value_counts()
old_product_counts = old_customers['Product Category'].value_counts()

# Bar plot for product categories sold by age groups
age_product_table.plot(kind='bar', figsize=(12, 8))
plt.title('Product Categories Sold by Age Groups')
plt.xlabel('Product Category')
plt.ylabel('Number of Sales')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Age Groups')
plt.show()

# %%
# Age,Price per Unit and Total Amount
#This shows how willing different age groups are to pay for products and their overall spending amounts.
#This information can be used to enhance pricing strategies and customer segmentation.
sns.pairplot(data[['Age', 'Price per Unit', 'Total Amount']])
plt.show()

# %%
# Marketing Strategy Recommendation
"""
**Marketing Strategy Recommendation:**

The analysis indicates that customer segmentation and product category analysis reveal the varying interests of different customer groups in different product categories. This segmentation can help us better understand customer behaviors and make our marketing strategies more effective.

**Recommendation and Action Step:**
Developing targeted marketing strategies for different customer segments can increase customer satisfaction and boost sales. For example:

1. **Targeted Advertising and Content Marketing:**
   - We can highlight Beauty and Clothing products to young customers through digital advertising and social media campaigns.
   - For middle-aged customers, we can focus on electronics and clothing products through content marketing and discount campaigns.

2. **Personalized Promotions and Loyalty Programs:**
   - Offering segment-specific discounts and promotions can increase customer loyalty.
   - For instance, we can offer special discounts or gift cards for new Beauty and Clothing products to young customers, and create loyalty programs for electronics and clothing products for middle-aged customers.
"""
